# %% [markdown]
# <a href="https://colab.research.google.com/github/SatyaSingh08/Project1/blob/master/Copy_of_U1W1_02_Introduction_to_Pandas_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Advanced Certification in AIML
# ## A Program by IIIT-H and TalentSprint
# ### Not For Grading

# %% [markdown]
# ## Learning Objective

# %% [markdown]
# At the end of this experiment, you will be able to :
#
# * Use Pandas Library

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### Description

# %% [markdown]
# The dataset choosen for this exercise is an employee dataset. The dataset contains the following information regarding a particular employee:
#
# * Emp ID
# * Name Prefix
# * First Name
# * Middle Initial
# * Last Name
# * Gender
# * E Mail
# * Father's Name
# * Mother's Name
# * Mother's Maiden Name
# * Date of Birth
# * Time of Birth
# * Age in Yrs
# *  Weight in Kgs
# * Date of Joining
# * Quarter of Joining
# * Half of Joining
# * Year of Joining
# * Month of Joining
# * Month Name of Joining
# * Short Month
# * Day of Joining
# * DOW of Joining
# * Short DOW
# * Age in Company (Years)
# * Salary
# * Last % Hike
# * SSN
# * Phone No
# * Place Name
# * CountyCity,
# * State
# * Zip
# * Region
# * User Name
# * Password

# %% [markdown]
# ### Setup Steps

# %%
#@title Please enter your registration id to start: { run: "auto", display-mode: "form" }
Id = "2200718" #@param {type:"string"}

# %%
#@title Please enter your password (normally your phone number) to continue: { run: "auto", display-mode: "form" }
password = "7717740929" #@param {type:"string"}

# %%
#@title Run this cell to complete the setup for this Notebook
from IPython import get_ipython

ipython = get_ipython()
  
notebook= "U1W1_02_Introduction_to_Pandas_1" #name of the notebook
Answer = "Ungraded"

def setup():
    ipython.magic("sx wget https://cdn.talentsprint.com/aiml/Experiment_related_data/Employee.csv")
    #ipython.magic("sx wget https://cdn.talentsprint.com/aiml/Experiment_related_data/Large_employee.csv")
    from IPython.display import HTML, display
    display(HTML('<script src="https://dashboard.talentsprint.com/aiml/record_ip.html?traineeId={0}&recordId={1}"></script>'.format(getId(),submission_id)))
    print("Setup completed successfully")
    return

def submit_notebook():
    
    ipython.magic("notebook -e "+ notebook + ".ipynb")
    
    import requests, json, base64, datetime

    url = "https://dashboard.talentsprint.com/xp/app/save_notebook_attempts"
    if not submission_id:
      data = {"id" : getId(), "notebook" : notebook, "mobile" : getPassword()}
      r = requests.post(url, data = data)
      r = json.loads(r.text)

      if r["status"] == "Success":
          return r["record_id"]
      elif "err" in r:        
        print(r["err"])
        return None        
      else:
        print ("Something is wrong, the notebook will not be submitted for grading")
        return None

    elif getAnswer() and getComplexity() and getAdditional() and getConcepts():
      f = open(notebook + ".ipynb", "rb")
      file_hash = base64.b64encode(f.read())

      data = {"complexity" : Complexity, "additional" :Additional, 
              "concepts" : Concepts, "record_id" : submission_id, 
              "answer" : Answer, "id" : Id, "file_hash" : file_hash,
              "feedback_experiments_input" : Comments, "notebook" : notebook}

      r = requests.post(url, data = data)
      r = json.loads(r.text)
      if "err" in r:        
        print(r["err"])
        return None   
      else:
        print("Your submission is successful.")
        print("Ref Id:", submission_id)
        print("Date of submission: ", r["date"])
        print("Time of submission: ", r["time"])
        print("View your submissions: https://aiml.iiith.talentsprint.com/notebook_submissions")
        # print("For any queries/discrepancies, please connect with mentors through the chat icon in LMS dashboard.")
      return submission_id
    else: submission_id
    

def getAdditional():
  try:
    if not Additional: 
      raise NameError
    else:
      return Additional  
  except NameError:
    print ("Please answer Additional Question")
    return None
def getComments():
  try:
    if not Comments:
      raise NameError
    else:
      return Comments
  except NameError:
    print ("Please answer Comments Question")
    return None

def getComplexity():
  try:
    if not Complexity:
      raise NameError
    else:
      return Complexity
  except NameError:
    print ("Please answer Complexity Question")
    return None
  
def getConcepts():
  try:
    if not Concepts:
      raise NameError
    else:
      return Concepts
  except NameError:
    print ("Please answer Concepts Question")
    return None

def getAnswer():
  try:
    if not Answer:
      raise NameError 
    else: 
      return Answer
  except NameError:
    print ("Please answer Question")
    return None

def getId():
  try: 
    return Id if Id else None
  except NameError:
    return None

def getPassword():
  try:
    return password if password else None
  except NameError:
    return None

submission_id = None
### Setup 
if getPassword() and getId():
  submission_id = submit_notebook()
  if submission_id:
    setup()
    
else:
  print ("Please complete Id and Password cells before running setup")
# Out:
# <script src="https://dashboard.talentsprint.com/aiml/record_ip.html?traineeId=2200718&recordId=9791"></script>
# Setup completed successfully

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# ### 1. Load the dataset with index as 'Emp Id'

# %%
import pandas as pd

# %%
dataset = pd.read_csv("Employee.csv")
# YOUR CODE HERE

# %%
dataset.columns
# Out:
# Index(['Emp ID', 'Name Prefix', 'First Name', 'Middle Initial', 'Last Name',
#        'Gender', 'E Mail', 'Father's Name', 'Mother's Name',
#        'Mother's Maiden Name', 'Date of Birth', 'Time of Birth', 'Age in Yrs.',
#        'Weight in Kgs.', 'Date of Joining', 'Quarter of Joining',
#        'Half of Joining', 'Year of Joining', 'Month of Joining',
#        'Month Name of Joining', 'Short Month', 'Day of Joining',
#        'DOW of Joining', 'Short DOW', 'Age in Company (Years)', 'Salary',
#        'Last % Hike', 'SSN', 'Phone No. ', 'Place Name', 'County', 'City',
#        'State', 'Zip', 'Region', 'User Name', 'Password'],
#       dtype='object')

# %%
dataset.set_index("Emp ID", inplace=True)

# %% [markdown]
# ### 2. Display the first 5 entries of the dataset

# %%
# YOUR CODE HERE
dataset.head()
# Out:
#        Name Prefix First Name Middle Initial Last Name Gender  \
# Emp ID
# 677509        Drs.       Lois              H    Walker      F
# 940761         Ms.     Brenda              S  Robinson      F
# 428945         Dr.        Joe              W  Robinson      M
# 408351        Drs.      Diane              I     Evans      F
# 193819         Mr.   Benjamin              R   Russell      M
#
#                               E Mail     Father's Name       Mother's Name  \
# Emp ID
# 677509       lois.walker@hotmail.com     Donald Walker        Helen Walker
# 940761     brenda.robinson@gmail.com  Raymond Robinson       Judy Robinson
# 428945        joe.robinson@gmail.com    Scott Robinson  Stephanie Robinson
# 408351         diane.evans@yahoo.com       Jason Evans      Michelle Evans
# 193819  benjamin.russell@charter.net   Gregory Russell   Elizabeth Russell
#
#        Mother's Maiden Name Date of Birth  ...          SSN    Phone No.   \
# Emp ID                                     ...
# 677509                Lewis     3/29/1981  ...  467-99-4677  303-572-8492
# 940761                Perry     7/31/1970  ...  537-71-4566  225-945-4954
# 428945               Taylor     6/16/1963  ...  025-92-3584  219-904-2161
# 408351                Allen     12/4/1977  ...  314-35-9851  215-793-6791
# 193819               Nelson     4/17/1977  ...  121-98-7248  262-404-2252
#
#           Place Name    County          City State    Zip     Region  \
# Emp ID
# 677509        Denver    Denver        Denver    CO  80224       West
# 940761     Stonewall   De Soto     Stonewall    LA  71078      South
# 428945  Michigantown   Clinton  Michigantown    IN  46057    Midwest
# 408351      Hydetown  Crawford      Hydetown    PA  16328  Northeast
# 193819       Fremont   Waupaca       Fremont    WI  54940    Midwest
#
#          User Name        Password
# Emp ID
# 677509    lhwalker   DCa}.T}X:v?NP
# 940761  bsrobinson   TCo\j#Zg;SQ~o
# 428945  jwrobinson    GO4$J8MiEh[A
# 408351     dievans   0gGRtp1HfL<r5
# 193819   brrussell  Rd<Y8cp!@R;*%F
#
# [5 rows x 36 columns]

# %% [markdown]
# ### 3. How many  records are there in the dataset?

# %%
# YOUR CODE HERE
dataset.shape
# Out:
# (100, 36)

# %% [markdown]
# ### 4. How many columns are there in the dataset?

# %%
# YOUR CODE HERE
len(dataset.columns)
# Out:
# 36

# %% [markdown]
# ### 5. Print the name of all the columns in the dataset

# %%
# YOUR CODE HERE
columns = dataset.columns

# %% [markdown]
# ### 6. What is  the name of the 20th column ?

# %%
# YOUR CODE HERE
columns[19]
# Out:
# 'Short Month'

# %% [markdown]
# ### 7. What is  the datatype of each column in the dataset?

# %%
# YOUR CODE HERE
dataset.dtypes
# Out:
# Name Prefix                object
# First Name                 object
# Middle Initial             object
# Last Name                  object
# Gender                     object
# E Mail                     object
# Father's Name              object
# Mother's Name              object
# Mother's Maiden Name       object
# Date of Birth              object
# Time of Birth              object
# Age in Yrs.               float64
# Weight in Kgs.              int64
# Date of Joining            object
# Quarter of Joining         object
# Half of Joining            object
# Year of Joining             int64
# Month of Joining            int64
# Month Name of Joining      object
# Short Month                object
# Day of Joining              int64
# DOW of Joining             object
# Short DOW                  object
# Age in Company (Years)    float64
# Salary                      int64
# Last % Hike                object
# SSN                        object
# Phone No.                  object
# Place Name                 object
# County                     object
# City                       object
# State                      object
# Zip                         int64
# Region                     object
# User Name                  object
# Password                   object
# dtype: object

# %% [markdown]
# ### 8. Display the columns from 5 to 9 and rows 1 to 3 of the dataset

# %%
# YOUR CODE HERE
dataset.iloc[1:3, 5:9]
# Out:
#                            E Mail     Father's Name       Mother's Name  \
# Emp ID
# 940761  brenda.robinson@gmail.com  Raymond Robinson       Judy Robinson
# 428945     joe.robinson@gmail.com    Scott Robinson  Stephanie Robinson
#
#        Mother's Maiden Name
# Emp ID
# 940761                Perry
# 428945               Taylor

# %% [markdown]
# ### 9. Display all the rows after 50th row of the dataset

# %%
# YOUR CODE HERE
dataset.iloc[50:]
# Out:
#        Name Prefix   First Name Middle Initial   Last Name Gender  \
# Emp ID
# 958326         Mr.        Larry              T      Miller      M
# 447813        Mrs.          Ann              Q     Coleman      F
# 525955        Drs.         Judy              C    Gonzales      F
# 818384         Mr.        Peter              X  Washington      M
# 761821            Franklin             Saranac Lake    NY  12983  Northeast
# 400173        Philadelphia             Philadelphia    PA  19132  Northeast
# 802554       Pointe Coupee                  Jarreau    LA  70749      South
# 476433            Sedgwick                  Wichita    KS  67214    Midwest
# 533952               Major                     Meno    OK  73760      South
# 623929              Oneida                 Oriskany    NY  13424  Northeast
# 844177                Ross            Richmond Dale    OH  45673    Midwest
# 212893          Miami-Dade                    Miami    FL  33166      South
# 185032              Racine                   Racine    WI  53490    Midwest
# 867084         North Slope                  Atqasuk    AK  99791       West
# 969964             Johnson  Whiteman Air Force Base    MO  65305    Midwest
# 158666                Inyo             Independence    CA  93526       West
# 489424                Lane                 Mapleton    OR  97453       West
# 639892            Harrison                   Biloxi    MS  39532      South
# 704709        Carol Stream             Carol Stream    IL  60351    Midwest
# 461593               Wayne                  Detroit    MI  48278    Midwest
# 392491  Yukon-Koyukuk (CA)                 Mc Grath    AK  99627       West
# 495141             Gratiot                     Alma    MI  48801    Midwest
#
#            User Name         Password
# Emp ID
# 958326      ltmiller     2WgF#:ew**x#
# 447813     aqcoleman        g2]GlvlL5
# 525955    jcgonzales   yDl}pfaWs{Hro6
# 818384  pxwashington  97%d^2rk41!E>*Q
# 971640        caross     h&jmac@+QD?B
# 253573       selopez        GsP~S?FYY
# 904898      aqcooper       i_^#>]tFpt
# 515103       aaperez         y;n9A#}b
# 491943      nphoward        OC\&tG&?c
# 750173     arroberts      h>.g!B:VcNN
# 687017      fpwatson   rjV1$at!wq53a$
# 241882        dgwood  iO8B@*yA*mG6b9o
# 758872     hyjenkins         zPnRU5Bo
# 940922      mxbutler       hY3BqUR>6F
# 917937        thhall     Lgdb8q<0L@-/
# 917395      cdnelson   QKae{1EP1A[SeX
# 183071      apgarcia     eI!^kXR]Q^V+
# 316110     jisanchez  Yg#Z+:CDwDV<*xZ
# 293459    sjphillips      ht}X55$P&g1
# 732017     cjramirez   qP-#AhuNuz*Wb]
# 915638    jwanderson     a3Hlk+.V/TjD
# 478003       cxwhite   mofyGR>.?Dwb4!
# 951225      mnbrooks     0*2k8uW&:{i{
# 883936      diflores   9||FLq|0tU|9>v
# 528673      pvwatson     7q{iHhbgWZ7%
# 765850       lrmoore    0jj}jl_r/VmJ;
# 262382      comiller      Nr-t/.^cWBO
# 870820  mgwashington      ju$7I]eH8{-
# 806955   wghernandez     BRB3DFywgZZ4
# 325319       cfprice        K*$u@MAoH
# 623253     rqstewart    C\RjCUPJd[Ld]
# 225925      pdcooper       hW%ZbJ\fZ-
# 761821  egwashington         B\Wb^6W-
# 400173     dkedwards    VWEIm3YKm65|D
# 802554   rvalexander    3N3]VFZx?MaC{
# 476433    lnmitchell         Ty/b@+;f
# 533952       kradams    OfK?#J|7&W\1T
# 623929      jrhoward   0v+|SfA0Xv+Pf%
# 844177       mtallen    oC1OHlW%Sk@%6
# 212893   jyhenderson       g-oCs-L/za
# 185032       edperez       g]SJn<W_/#
# 867084       desmith         C[WxHsB9
# 969964      jsparker        8wUbWmuib
# 158666     rastewart   7ONuh3Zi^z#32r
# 489424       pfwhite   8<Mc.5]eu.*C8.
# 639892        jkhill  a_!SKb6h3?w*Mad
# 704709      hznelson      z/-hEz3&^q5
# 461593        noward   AUe6s0@:@]A3Ze
# 392491      trmurphy        V]PGw>4h9
# 495141       tbyoung  d6!&xu12A1H^i![
#
# [50 rows x 36 columns]

# %% [markdown]
# ### 10. Display the columns from 10 to 12 for first 50 rows of the dataset

# %%
# YOUR CODE HERE
dataset.iloc[:50, 10:12]
# Out:
#        Time of Birth  Age in Yrs.
# Emp ID
# 677509   02:31:49 AM        36.36
# 940761   12:13:27 PM        47.02
# 428945   10:45:36 AM        54.15
# 408351   02:18:45 AM        39.67
# 193819   05:41:11 PM        40.31
# 499687   01:12:41 PM        34.86
# 539712   08:56:32 PM        22.14
# 380086   10:39:33 AM        59.12
# 477616   04:38:47 PM        58.18
# 162402   03:59:26 AM        29.73
# 231469   02:15:50 AM        42.50
# 153989   04:33:57 PM        22.21
# 386158   06:04:57 PM        45.45
# 301576   12:23:21 AM        21.10
# 441771   06:59:29 PM        59.47
# 528509   08:11:15 PM        50.97
# 912990   03:47:46 AM        47.23
# 214352   09:20:52 AM        24.66
# 890290   09:24:39 PM        58.08
# 622406   08:28:14 PM        49.85
# 979607   09:28:36 AM        22.64
# 969580   01:37:48 AM        23.77
# 426038   11:14:04 AM        44.72
# 388642   01:08:30 PM        37.27
# 560455   12:52:37 PM        59.42
# 477253   02:57:12 AM        28.02
# 263480   07:24:56 PM        27.59
# 683826   03:46:56 PM        48.09
# 474599   11:07:50 PM        42.39
# 335732   03:15:30 AM        53.68
# 329752   12:00:55 AM        36.24
# 893212   04:20:22 AM        36.14
# 621833   12:23:15 AM        23.92
# 456747   12:13:48 AM        26.24
# 278556   06:30:29 AM        24.02
# 333476   01:45:41 AM        49.69
# 218791   03:42:13 AM        48.49
# 134841   05:05:35 AM        33.89
# 726264   02:18:24 PM        43.63
# 766610   02:54:56 AM        55.97
# 923947   12:02:11 AM        55.14
# 227922   02:43:26 AM        35.02
# 265813   02:25:34 PM        32.58
# 247137   09:46:54 PM        38.65
# 407061   05:45:35 AM        52.99
# 226714   02:51:17 AM        33.73
# 702813   10:28:03 PM        27.73
# 524896   05:49:46 AM        56.38
# 363065   03:06:00 AM        23.73
# 879753   03:43:43 AM        21.30

# %% [markdown]
# ### 11. Display the information of the employees who have  joined in Quarter 1 and 4.

# %%
dataset['Quarter of Joining']
# Out:
# Emp ID
# 677509    Q4
# 940761    Q3
# 428945    Q3
# 408351    Q2
# 193819    Q3
#           ..
# 639892    Q3
# 704709    Q3
# 461593    Q1
# 392491    Q3
# 495141    Q2
# Name: Quarter of Joining, Length: 100, dtype: object

# %%
# YOUR CODE HERE
data = dataset[dataset['Quarter of Joining'].isin(["Q1","Q4"])]

# %%
data['Quarter of Joining']
# Out:
# Emp ID
# 677509    Q4
# 380086    Q1
# 162402    Q1
# 153989    Q1
# 386158    Q4
# 441771    Q4
# 214352    Q1
# 890290    Q1
# 969580    Q1
# 426038    Q4
# 477253    Q4
# 263480    Q1
# 683826    Q1
# 474599    Q4
# 333476    Q4
# 407061    Q1
# 702813    Q1
# 524896    Q4
# 363065    Q4
# 958326    Q1
# 447813    Q4
# 525955    Q1
# 818384    Q4
# 971640    Q4
# 253573    Q1
# 904898    Q1
# 491943    Q1
# 241882    Q1
# 940922    Q1
# 917395    Q4
# 293459    Q1
# 732017    Q1
# 478003    Q1
# 870820    Q1
# 806955    Q1
# 325319    Q4
# 761821    Q1
# 400173    Q4
# 476433    Q4
# 623929    Q4
# 212893    Q4
# 185032    Q4
# 867084    Q1
# 489424    Q1
# 461593    Q1
# Name: Quarter of Joining, dtype: object

# %%
data1 = dataset[(dataset['Quarter of Joining'] == 'Q1') | (dataset['Quarter of Joining'] == 'Q4')]

# %%
data1['Quarter of Joining']
# Out:
# Emp ID
# 677509    Q4
# 380086    Q1
# 162402    Q1
# 153989    Q1
# 386158    Q4
# 441771    Q4
# 214352    Q1
# 890290    Q1
# 969580    Q1
# 426038    Q4
# 477253    Q4
# 263480    Q1
# 683826    Q1
# 474599    Q4
# 333476    Q4
# 407061    Q1
# 702813    Q1
# 524896    Q4
# 363065    Q4
# 958326    Q1
# 447813    Q4
# 525955    Q1
# 818384    Q4
# 971640    Q4
# 253573    Q1
# 904898    Q1
# 491943    Q1
# 241882    Q1
# 940922    Q1
# 917395    Q4
# 293459    Q1
# 732017    Q1
# 478003    Q1
# 870820    Q1
# 806955    Q1
# 325319    Q4
# 761821    Q1
# 400173    Q4
# 476433    Q4
# 623929    Q4
# 212893    Q4
# 185032    Q4
# 867084    Q1
# 489424    Q1
# 461593    Q1
# Name: Quarter of Joining, dtype: object

# %% [markdown]
# ### 12. How many people are from the southern region joined on Monday?

# %%
# YOUR CODE HERE
data['Region'].unique()
# Out:
# array(['West', 'Midwest', 'South', 'Northeast'], dtype=object)

# %%
data['DOW of Joining'].unique()
# Out:
# array(['Monday', 'Friday', 'Thursday', 'Tuesday', 'Wednesday', 'Sunday',
#        'Saturday'], dtype=object)

# %%
len(dataset[(dataset['Region'] == 'South') & (dataset['DOW of Joining'] == 'Monday')])
# Out:
# 9

# %% [markdown]
# ### 13. Display the information of the employees who have more than 13 years experience in the company

# %%
# YOUR CODE HERE
dataset[dataset['Year of Joining']>13]
# Out:
#        Name Prefix First Name Middle Initial Last Name Gender  \
# Emp ID
# 677509        Drs.       Lois              H    Walker      F
# 940761         Ms.     Brenda              S  Robinson      F
# 428945         Dr.        Joe              W  Robinson      M
# 408351        Drs.      Diane              I     Evans      F
# 193819         Mr.   Benjamin              R   Russell      M
# ...            ...        ...            ...       ...    ...
# 639892         Mr.       Jose              K      Hill      M
# 704709         Dr.     Harold              Z    Nelson      M
# 461593         Ms.     Nicole              O      Ward      F
# 392491        Mrs.    Theresa              R    Murphy      F
# 495141        Drs.      Tammy              B     Young      F
#
#                               E Mail     Father's Name       Mother's Name  \
# Emp ID
# 677509       lois.walker@hotmail.com     Donald Walker        Helen Walker
# 940761     brenda.robinson@gmail.com  Raymond Robinson       Judy Robinson
# 428945        joe.robinson@gmail.com    Scott Robinson  Stephanie Robinson
# 408351         diane.evans@yahoo.com       Jason Evans      Michelle Evans
# 193819  benjamin.russell@charter.net   Gregory Russell   Elizabeth Russell
# ...                              ...               ...                 ...
# 639892         jose.hill@hotmail.com       Carlos Hill           Anna Hill
# 704709       harold.nelson@gmail.com    Richard Nelson       Pamela Nelson
# 461593         nicole.ward@yahoo.com        Ralph Ward          Julia Ward
# 392491      theresa.murphy@gmail.com     George Murphy   Jacqueline Murphy
# 495141       tammy.young@comcast.net      Andrew Young        Brenda Young
#
#        Mother's Maiden Name Date of Birth  ...          SSN    Phone No.   \
# Emp ID                                     ...
# 677509                Lewis     3/29/1981  ...  467-99-4677  303-572-8492
# 940761                Perry     7/31/1970  ...  537-71-4566  225-945-4954
# 428945               Taylor     6/16/1963  ...  025-92-3584  219-904-2161
# 408351                Allen     12/4/1977  ...  314-35-9851  215-793-6791
# 193819               Nelson     4/17/1977  ...  121-98-7248  262-404-2252
# ...                     ...           ...  ...          ...           ...
# 639892                Hayes     10/8/1994  ...  171-86-3825  228-245-5000
# 704709                Smith    12/24/1984  ...  456-99-2066  217-555-9216
# 461593                  Lee    12/12/1964  ...  196-84-2551  231-761-7861
# 392491             Peterson    12/30/1987  ...  249-99-8801  907-356-1555
# 495141             Robinson     3/22/1979  ...  771-02-7046  231-290-3075
#
#           Place Name              County          City State    Zip  \
# Emp ID
# 677509        Denver              Denver        Denver    CO  80224
# 940761     Stonewall             De Soto     Stonewall    LA  71078
# 428945  Michigantown             Clinton  Michigantown    IN  46057
# 408351      Hydetown            Crawford      Hydetown    PA  16328
# 193819       Fremont             Waupaca       Fremont    WI  54940
# ...              ...                 ...           ...   ...    ...
# 639892        Biloxi            Harrison        Biloxi    MS  39532
# 704709  Carol Stream        Carol Stream  Carol Stream    IL  60351
# 461593       Detroit               Wayne       Detroit    MI  48278
# 392491      Mc Grath  Yukon-Koyukuk (CA)      Mc Grath    AK  99627
# 495141          Alma             Gratiot          Alma    MI  48801
#
#            Region   User Name         Password
# Emp ID
# 677509       West    lhwalker    DCa}.T}X:v?NP
# 940761      South  bsrobinson    TCo\j#Zg;SQ~o
# 428945    Midwest  jwrobinson     GO4$J8MiEh[A
# 408351  Northeast     dievans    0gGRtp1HfL<r5
# 193819    Midwest   brrussell   Rd<Y8cp!@R;*%F
# ...           ...         ...              ...
# 639892      South      jkhill  a_!SKb6h3?w*Mad
# 704709    Midwest    hznelson      z/-hEz3&^q5
# 461593    Midwest      noward   AUe6s0@:@]A3Ze
# 392491       West    trmurphy        V]PGw>4h9
# 495141    Midwest     tbyoung  d6!&xu12A1H^i![
#
# [100 rows x 36 columns]

# %% [markdown]
# ### 14. There is a lot of redundant data. For example, the information in the below columns is also available in the *Date of Joining* column.
#
#   1.   month of Joining
#   2.   year of Joining
#   3.   Day of Joining
#
# There could be other such columns containing redundant data. Please identify such columns and take appropriate action.
#
#
# You can refer to the below link :
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html

# %%
# YOUR CODE HERE
dataset.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### 15. Remove "%" sign from the "Last % Hike" column values of the dataset
#
# you can refer the below link :
#
# https://stackoverflow.com/questions/52850192/python-extract-last-letter-of-a-string-from-a-pandas-column

# %%
# YOUR CODE HERE
dataset.columns
# Out:
# Index(['Name Prefix', 'First Name', 'Middle Initial', 'Last Name', 'Gender',
#        'E Mail', 'Father's Name', 'Mother's Name', 'Mother's Maiden Name',
#        'Date of Birth', 'Time of Birth', 'Age in Yrs.', 'Weight in Kgs.',
#        'Date of Joining', 'Quarter of Joining', 'Half of Joining',
#        'Year of Joining', 'Month of Joining', 'Month Name of Joining',
#        'Short Month', 'Day of Joining', 'DOW of Joining', 'Short DOW',
#        'Age in Company (Years)', 'Salary', 'Last % Hike', 'SSN', 'Phone No. ',
#        'Place Name', 'County', 'City', 'State', 'Zip', 'Region', 'User Name',
#        'Password'],
#       dtype='object')

# %%
dataset.rename(columns={"Last % Hike" : "Last Hike"}, inplace=True)

# %%
# dataset['Last Hike'] = dataset['Last Hike'].str.strip.str(-1)
dataset['Last Hike'] = [x.strip('%') for x in dataset['Last Hike']]

# %%
dataset['Last Hike']
# Out:
# Emp ID
# 677509    21
# 940761    27
# 428945    16
# 408351     1
# 193819    13
#           ..
# 639892    15
# 704709     0
# 461593    12
# 392491    11
# 495141     7
# Name: Last Hike, Length: 100, dtype: object

# %% [markdown]
# ### 16. How many Female employees got hike more than 20% ?

# %%
dataset['Last Hike']
# Out:
# Emp ID
# 677509    21
# 940761    27
# 428945    16
# 408351     1
# 193819    13
#           ..
# 639892    15
# 704709     0
# 461593    12
# 392491    11
# 495141     7
# Name: Last Hike, Length: 100, dtype: object

# %%
# YOUR CODE HERE
len(dataset[(dataset['Last Hike']>'20')])
# Out:
# 58

# %% [markdown]
# ### Summary

# %% [markdown]
# To know more about Pandas, you can refer below link :
#
# https://www.machinelearningplus.com/python/101-pandas-exercises-python/

# %% [markdown]
# ## Please answer the questions below to complete the experiment:

# %%
#@title How was the experiment? { run: "auto", form-width: "500px", display-mode: "form" }
Complexity = "" #@param ["","Too Simple, I am wasting time", "Good, But Not Challenging for me", "Good and Challenging for me", "Was Tough, but I did it", "Too Difficult for me"]

# %%
#@title If it was too easy, what more would you have liked to be added? If it was very difficult, what would you have liked to have been removed? { run: "auto", display-mode: "form" }
Additional = "" #@param {type:"string"}

# %%
#@title Can you identify the concepts from the lecture which this experiment covered? { run: "auto", vertical-output: true, display-mode: "form" }
Concepts = "" #@param ["","Yes", "No"]

# %%
#@title  Text and image description/explanation and code comments within the experiment: { run: "auto", vertical-output: true, display-mode: "form" }
Comments = "" #@param ["","Very Useful", "Somewhat Useful", "Not Useful", "Didn't use"]

# %%
#@title Run this cell to submit your notebook  { vertical-output: true }
try:
  if submission_id:
      return_id = submit_notebook()
      if return_id : submission_id =return_id
  else:
      print("Please complete the setup first.")
except NameError:
  print ("Please complete the setup first.")
